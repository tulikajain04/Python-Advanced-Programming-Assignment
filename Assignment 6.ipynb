# %% [markdown]
# ### 1. You are given two strings s and t. String t is generated by randomly
# shuffling string s and then adding one more letter at a random position.
# Return the letter that was added to t.
# Examples
# find_the_difference(&quot;abcd&quot;, &quot;abcde&quot;) ➞ &quot;e&quot;
# find_the_difference(&quot;&quot;, &quot;y&quot;) ➞ &quot;y&quot;
# find_the_difference(&quot;ae&quot;, &quot;aea&quot;) ➞ &quot;a&quot;

# %%
def find_the_difference(a,b):
    s=list(b)
    for i in a:
        if(i in s):
            s.pop(s.index(i))
    output=','.join(s)
    print(f'find_the_difference("{a}","{b}") -> "{output}"')

# %%
find_the_difference("abcd", "abcde")
# Out:
# find_the_difference("abcd","abcde") -> "e"

# %%
find_the_difference("", "y")
# Out:
# find_the_difference("","y") -> "y"

# %%
find_the_difference("ae", "aea")
# Out:
# find_the_difference("ae","aea") -> "a"

# %% [markdown]
# ### 2. Given a function that accepts unlimited arguments, check and count how
# many data types are in those arguments. Finally return the total in a list.
# List order is:
# [int, str, bool, list, tuple, dictionary]
# Examples
# count_datatypes(1, 45, &quot;Hi&quot;, False) ➞ [2, 1, 1, 0, 0, 0]
# count_datatypes([10, 20], (&quot;t&quot;, &quot;Ok&quot;), 2, 3, 1) ➞ [3, 0, 0, 1, 1, 0]
# count_datatypes(&quot;Hello&quot;, &quot;Bye&quot;, True, True, False, {&quot;1&quot;: &quot;One&quot;, &quot;2&quot;: &quot;Two&quot;}, [1,
# 3], {&quot;Brayan&quot;: 18}, 25, 23) ➞ [2, 2, 3, 1, 0, 2]
# count_datatypes(4, 21, (&quot;ES&quot;, &quot;EN&quot;), (&quot;a&quot;, &quot;b&quot;), False, [1, 2, 3], [4, 5, 6]) ➞ [2,
# 0, 1, 2, 2, 0]

# %%
def count_datatypes(*args):
    
    cl=[0,0,0,0,0,0]
    for i in args:
        if(type(i)==int):
            cl[0]+=1
        elif(type(i)==str):
            cl[1]+=1
        elif(type(i)==bool):
            cl[2]+=1
        elif(type(i)==list):
            cl[3]+=1
        elif(type(i)==tuple):
            cl[4]+=1
        elif(type(i)==dict):
            cl[5]+=1
    print(f'count_datatypes({args}) -> {cl}')

# %%
count_datatypes(1, 45, "Hi", False)
# Out:
# count_datatypes((1, 45, 'Hi', False)) -> [2, 1, 1, 0, 0, 0]

# %%
count_datatypes([10, 20], ("t", "Ok"), 2, 3, 1)
# Out:
# count_datatypes(([10, 20], ('t', 'Ok'), 2, 3, 1)) -> [3, 0, 0, 1, 1, 0]

# %%
count_datatypes("Hello", "Bye", True, True, False, {"1": "One", "2": "Two"}, [1, 3], {"Brayan": 18}, 25, 23)
# Out:
# count_datatypes(('Hello', 'Bye', True, True, False, {'1': 'One', '2': 'Two'}, [1, 3], {'Brayan': 18}, 25, 23)) -> [2, 2, 3, 1, 0, 2]

# %%
count_datatypes(4, 21, ("ES", "EN"), ("a", "b"), False, [1, 2, 3], [4, 5, 6])
# Out:
# count_datatypes((4, 21, ('ES', 'EN'), ('a', 'b'), False, [1, 2, 3], [4, 5, 6])) -> [2, 0, 1, 2, 2, 0]

# %% [markdown]
# ### 3. A Fibonacci string is a precedence of the Fibonacci series. It works with
# any two characters of the English alphabet (as opposed to the numbers 0 and
# 1 in the Fibonacci series) as the initial items and concatenates them together
# as it progresses in a similar fashion as the Fibonacci series.
# Examples
# fib_str(3, [&quot;j&quot;, &quot;h&quot;]) ➞ &quot;j, h, hj&quot;
# fib_str(5, [&quot;e&quot;, &quot;a&quot;]) ➞ &quot;e, a, ae, aea, aeaae&quot;
# fib_str(6, [&quot;n&quot;, &quot;k&quot;]) ➞ &quot;n, k, kn, knk, knkkn, knkknknk&quot;

# %%
def fib_str(n,l):
    li=l
    if(n>2):
        for i in range(2,n):
            li.append(li[-1]+li[-2])
    print(f'finb_str{n,l} -> {",".join(li)}')

# %%
fib_str(3, ["j", "h"])
# Out:
# finb_str(3, ['j', 'h', 'hj']) -> j,h,hj

# %%
fib_str(6, ["n", "k"])
# Out:
# finb_str(6, ['n', 'k', 'kn', 'knk', 'knkkn', 'knkknknk']) -> n,k,kn,knk,knkkn,knkknknk

# %%
fib_str(5, ["e", "a"])
# Out:
# finb_str(5, ['e', 'a', 'ae', 'aea', 'aeaae']) -> e,a,ae,aea,aeaae

# %% [markdown]
# ### 4. Given an integer between 0 and 26, make a variable (self.answer). That variable would be assigned to a string in this format:
# "nines:your answer, threes:your answer, ones:your answer"
# You need to find out how many ones, threes, and nines it would at least take for the number of each to add up to the given integer when multiplied by one, three or nine (depends).
# Examples:
# ones_threes_nines(10) ➞ "nines:1, threes:0, ones:1"
# ones_threes_nines(15) ➞ "nines:1, threes:2, ones:0"
# ones_threes_nines(22) ➞ "nines:2, threes:1, ones:1"

# %%
def ones_threes_nines(n):
    num=n
    output={"nines":0,"threes":0,"ones":0}
    while(num!=0):
        if(num>=9):
            num-=9
            output["nines"]+=1
        elif(num>=3):
            num-=3
            output["threes"]+=1
        elif(num>=1):
            num-=1
            output["ones"]+=1
        
    
    
    print(f'ones_threes_nines({n}) -> \"nines:{output["nines"]},threes:{output["threes"]},ones:{output["ones"]}\"')

# %%
ones_threes_nines(22)
# Out:
# ones_threes_nines(22) -> "nines:2,threes:1,ones:1"

# %%
ones_threes_nines(10)
# Out:
# ones_threes_nines(10) -> "nines:1,threes:0,ones:1"

# %%
ones_threes_nines(15)
# Out:
# ones_threes_nines(15) -> "nines:1,threes:2,ones:0"

# %% [markdown]
# ### 5. The Fibonacci sequence is a classic use case for recursive functions since the value of the sequence at a given index is dependent on the sum of the last two values. However, the recursion tree created by solving the Fibonacci sequence recursively can grow quite fast. Therefore it can be important to think about the implications of running a function recursively. Depending on the size of n needed and the capabilities of the system in question you might want to take a different approach.
# Write a non-recursive function that takes an integer n and returns the Fibonacci sequence's value at index n.
# Examples:
# fib(6) ➞ 8
# ## 0 + 1 = 1, 1 + 1 = 2, 1 + 2 = 3, 2 + 3 = 5, 3 + 5 = 8
# fib(1) ➞ 1
# fib(2) ➞ 1

# %%
def fib(n):
    a=0
    b=1
    for i in range(n-1):
        c=a+b
        a=b
        b=c
    print(f'fib({n}) -> {b}')

# %%
fib(6)
# Out:
# fib(6) -> 8

# %%
fib(1)
# Out:
# fib(1) -> 1

# %%
fib(2)
# Out:
# fib(2) -> 1
